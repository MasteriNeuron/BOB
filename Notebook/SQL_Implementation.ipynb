# %%
pip install mysql-connector-python
# Out:
# ...
#      ---------------------------------------- 7.9/7.9 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 904.2/904.2 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.22.1
#     Uninstalling protobuf-4.22.1:
#       Successfully uninstalled protobuf-4.22.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# ...
#
#   Using cached mysqlclient-2.1.1-cp39-cp39-win_amd64.whl (178 kB)
# ...

# %%
import pandas as pd
import json
import mysql.connector

# %%
def print_mysql_output(cursor):
    print("--START--")
    rows = cursor.fetchall()
    for r in rows:
        print(r)
    print("--END--\n")

# %%
host= "localhost"
user= "root"
password= "mysql"

# %%
db = mysql.connector.connect(
    host = host,
    user = user,
    password = password,
    )

# %%
cursor = db.cursor()

# %%
cursor.execute("show databases;")
print_mysql_output(cursor)
# Out:
# --START--
# ('apitest',)
# ('atanu11',)
# ('atanu123',)
# ('books',)
# ('dress_data',)
# ('ineuron_fsda',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('review',)
# ('sakila',)
# ('shop',)
# ('sys',)
# ('test123',)
# ('world',)
# ('youtube_scrapper',)
# ('youtubescrapping',)
# ('yt_channel_scraper',)
# --END--

# %%
cursor.execute("create database Youtube_db;")
print_mysql_output(cursor)
# Out:
# --START--
# --END--

# %%
cursor.execute("show databases;")
print_mysql_output(cursor)
# Out:
# --START--
# ('apitest',)
# ('atanu11',)
# ('atanu123',)
# ('books',)
# ('dress_data',)
# ('ineuron_fsda',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('review',)
# ('sakila',)
# ('shop',)
# ('sys',)
# ('test123',)
# ('world',)
# ('youtube_db',)
# ('youtube_scrapper',)
# ('youtubescrapping',)
# ('yt_channel_scraper',)
# --END--

# %%
data_df = pd.read_excel("data.xlsx")

# %%
data_df.head(3)
# Out:
#    Unnamed: 0   youtuber     username channelTitle  \
# 0           0  krishnaik  krishnaik06   Krish Naik
# 1           1  krishnaik  krishnaik06   Krish Naik
# 2           2  krishnaik  krishnaik06   Krish Naik
#
#                                                title           publishedAt  \
# 0  Tutorial 9-End To End ML Project-Deployment In...  2023-03-18T15:54:18Z
# 1  Tutorial 8-End To End ML Project-Create Predic...  2023-03-16T13:33:13Z
# 2  Tutorial 7-End To End ML Project-Model Hyperpa...  2023-03-14T11:47:18Z
#
#                                     thumbnailLink  \
# 0  https://i.ytimg.com/vi/gbJn2Ls2QsI/default.jpg
# 1  https://i.ytimg.com/vi/d6Jw5hGb65Y/default.jpg
# 2  https://i.ytimg.com/vi/oMZA8v4JECY/default.jpg
#
#                                      videoLink      videoId  viewCount  \
# 0  https://www.youtube.com/watch?v=gbJn2Ls2QsI  gbJn2Ls2QsI       6518
# 1  https://www.youtube.com/watch?v=d6Jw5hGb65Y  d6Jw5hGb65Y       5012
# ...

# %%
del data_df['Unnamed: 0']

# %%
data_df.head(3)
# Out:
#     youtuber     username channelTitle  \
# 0  krishnaik  krishnaik06   Krish Naik
# 1  krishnaik  krishnaik06   Krish Naik
# 2  krishnaik  krishnaik06   Krish Naik
#
#                                                title           publishedAt  \
# 0  Tutorial 9-End To End ML Project-Deployment In...  2023-03-18T15:54:18Z
# 1  Tutorial 8-End To End ML Project-Create Predic...  2023-03-16T13:33:13Z
# 2  Tutorial 7-End To End ML Project-Model Hyperpa...  2023-03-14T11:47:18Z
#
#                                     thumbnailLink  \
# 0  https://i.ytimg.com/vi/gbJn2Ls2QsI/default.jpg
# 1  https://i.ytimg.com/vi/d6Jw5hGb65Y/default.jpg
# 2  https://i.ytimg.com/vi/oMZA8v4JECY/default.jpg
#
#                                      videoLink      videoId  viewCount  \
# 0  https://www.youtube.com/watch?v=gbJn2Ls2QsI  gbJn2Ls2QsI       6518
# 1  https://www.youtube.com/watch?v=d6Jw5hGb65Y  d6Jw5hGb65Y       5012
# 2  https://www.youtube.com/watch?v=oMZA8v4JECY  oMZA8v4JECY       4725
#
# ...

# %%
from sqlalchemy import create_engine

# %%
username = "root"
password = "mysql"
dbname = 'youtube_db'
url = f"mysql://{username}:{password}@localhost/{dbname}"
url
# Out:
# 'mysql://root:mysql@localhost/youtube_db'

# %%
engine = create_engine(url)

# %%
data_df.to_sql(con=engine, name='youtubers_table', if_exists='replace', index=False)
# Out:
# 200

# %%
engine.dispose()

# %% [markdown]
# #### reconnecting to database

# %%
db = mysql.connector.connect(
    host = host,
    user = user,
    password = password,
    )

# %%
cursor = db.cursor()

# %%
cursor.execute("use youtube_db;")
print_mysql_output(cursor)
# Out:
# --START--
# --END--

# %%
cursor.execute("show tables;")
print_mysql_output(cursor)
# Out:
# --START--
# ('youtubers_table',)
# --END--

# %%
cursor.execute("describe youtubers_table;")
print_mysql_output(cursor)
# Out:
# --START--
# ('youtuber', b'text', 'YES', '', None, '')
# ('username', b'text', 'YES', '', None, '')
# ('channelTitle', b'text', 'YES', '', None, '')
# ('title', b'text', 'YES', '', None, '')
# ('publishedAt', b'text', 'YES', '', None, '')
# ('thumbnailLink', b'text', 'YES', '', None, '')
# ('videoLink', b'text', 'YES', '', None, '')
# ('videoId', b'text', 'YES', '', None, '')
# ('viewCount', b'bigint', 'YES', '', None, '')
# ('likeCount', b'bigint', 'YES', '', None, '')
# ('commentCount', b'bigint', 'YES', '', None, '')
# --END--

# %%
cursor.execute("select * from youtubers_table;")
print_mysql_output(cursor)
# Out:
# --START--
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 9-End To End ML Project-Deployment In AWS Cloud Using CICD Pipelines', '2023-03-18T15:54:18Z', 'https://i.ytimg.com/vi/gbJn2Ls2QsI/default.jpg', 'https://www.youtube.com/watch?v=gbJn2Ls2QsI', 'gbJn2Ls2QsI', 6518, 192, 24)
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 8-End To End ML Project-Create Prediction Pipeline Using Flask Web APP', '2023-03-16T13:33:13Z', 'https://i.ytimg.com/vi/d6Jw5hGb65Y/default.jpg', 'https://www.youtube.com/watch?v=d6Jw5hGb65Y', 'd6Jw5hGb65Y', 5012, 176, 29)
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 7-End To End ML Project-Model Hyperparameter Tuning', '2023-03-14T11:47:18Z', 'https://i.ytimg.com/vi/oMZA8v4JECY/default.jpg', 'https://www.youtube.com/watch?v=oMZA8v4JECY', 'oMZA8v4JECY', 4725, 144, 27)
# ...

# %% [markdown]
# ## Reading the Data from CSV

# %%
data_df = pd.read_excel("data.xlsx")

# %%
data_df.head(3)
# Out:
#    Unnamed: 0   youtuber     username channelTitle  \
# 0           0  krishnaik  krishnaik06   Krish Naik
# 1           1  krishnaik  krishnaik06   Krish Naik
# 2           2  krishnaik  krishnaik06   Krish Naik
#
#                                                title           publishedAt  \
# 0  Tutorial 9-End To End ML Project-Deployment In...  2023-03-18T15:54:18Z
# 1  Tutorial 8-End To End ML Project-Create Predic...  2023-03-16T13:33:13Z
# 2  Tutorial 7-End To End ML Project-Model Hyperpa...  2023-03-14T11:47:18Z
#
#                                     thumbnailLink  \
# 0  https://i.ytimg.com/vi/gbJn2Ls2QsI/default.jpg
# 1  https://i.ytimg.com/vi/d6Jw5hGb65Y/default.jpg
# 2  https://i.ytimg.com/vi/oMZA8v4JECY/default.jpg
#
#                                      videoLink      videoId  viewCount  \
# 0  https://www.youtube.com/watch?v=gbJn2Ls2QsI  gbJn2Ls2QsI       6518
# 1  https://www.youtube.com/watch?v=d6Jw5hGb65Y  d6Jw5hGb65Y       5012
# ...

# %%
del data_df['Unnamed: 0']

# %%
data_df
# Out:
#       youtuber     username channelTitle  \
# 0    krishnaik  krishnaik06   Krish Naik
# 1    krishnaik  krishnaik06   Krish Naik
# 2    krishnaik  krishnaik06   Krish Naik
# 3    krishnaik  krishnaik06   Krish Naik
# 4    krishnaik  krishnaik06   Krish Naik
# ..         ...          ...          ...
# 195    Telusko      Telusko      Telusko
# 196    Telusko      Telusko      Telusko
# 197    Telusko      Telusko      Telusko
# 198    Telusko      Telusko      Telusko
# 199    Telusko      Telusko      Telusko
#
#                                                  title           publishedAt  \
# 0    Tutorial 9-End To End ML Project-Deployment In...  2023-03-18T15:54:18Z
# 1    Tutorial 8-End To End ML Project-Create Predic...  2023-03-16T13:33:13Z
# 2    Tutorial 7-End To End ML Project-Model Hyperpa...  2023-03-14T11:47:18Z
# 3    Tutorial 6-End To End ML Project-Model Trainin...  2023-03-13T03:29:28Z
# 4    Tutorial 5-End To End ML Project-Data Transfor...  2023-03-11T12:03:01Z
# ...

# %%
data_df.columns
# Out:
# Index(['youtuber', 'username', 'channelTitle', 'title', 'publishedAt',
#        'thumbnailLink', 'videoLink', 'videoId', 'viewCount', 'likeCount',
#        'commentCount'],
#       dtype='object')

# %% [markdown]
# ## Adding Data to SQL Database

# %%
from sqlalchemy import create_engine

# %%
username = "root"
password = "mysql"
dbname = 'youtube_db'
url = f"mysql://{username}:{password}@localhost/{dbname}"
url
# Out:
# 'mysql://root:mysql@localhost/youtube_db'

# %%
engine = create_engine(url)

# %%
data_df.to_sql(con=engine, name='youtubers_table', if_exists='replace', index = False)

# %%
cursor.execute("show tables;")
print_mysql_output(cursor)
# Out:
# --START--
# ('youtubers_table',)
# --END--

# %%
cursor.execute("select * from youtubers_table;")
print_mysql_output(cursor)
# Out:
# --START--
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 9-End To End ML Project-Deployment In AWS Cloud Using CICD Pipelines', '2023-03-18T15:54:18Z', 'https://i.ytimg.com/vi/gbJn2Ls2QsI/default.jpg', 'https://www.youtube.com/watch?v=gbJn2Ls2QsI', 'gbJn2Ls2QsI', 6518, 192, 24)
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 8-End To End ML Project-Create Prediction Pipeline Using Flask Web APP', '2023-03-16T13:33:13Z', 'https://i.ytimg.com/vi/d6Jw5hGb65Y/default.jpg', 'https://www.youtube.com/watch?v=d6Jw5hGb65Y', 'd6Jw5hGb65Y', 5012, 176, 29)
# ('krishnaik', 'krishnaik06', 'Krish Naik', 'Tutorial 7-End To End ML Project-Model Hyperparameter Tuning', '2023-03-14T11:47:18Z', 'https://i.ytimg.com/vi/oMZA8v4JECY/default.jpg', 'https://www.youtube.com/watch?v=oMZA8v4JECY', 'oMZA8v4JECY', 4725, 144, 27)
# ...
